# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import rcParams

# %%
rcParams['font.family'] = 'Times New Roman'
rcParams['font.size'] = 16
np.set_printoptions(precision = 2)
x = np.arange(0,1, 0.01)
y = x.copy()
X, Y = np.meshgrid(x, y)
wx = 0.1
wy = 0.3
S = wx*X+wy*Y
out = S > 0.15
fig, ax = plt.subplots(1, 1)
ax.imshow(out)
ticks = np.around(np.arange(-0.2, 1.1, 0.2), 3)
ax.set_xticklabels(ticks)
ax.set_yticklabels(ticks)
plt.gca().invert_yaxis()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12488\2966595813.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ticks)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12488\2966595813.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ticks)
